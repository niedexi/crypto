# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time


bn = 'https://api.binance.com/api/v1/klines?symbol=LTCUSDT&interval=1d&limit=999'
# r = requests.get(bn).json()

chart = pd.read_json(bn)

name = ['ot', 'open', 'high', 'low', 'close', 'volume', 'ct', 'qv', 'trades', 'tbv', 'tbqv', 'ignore']
chart.columns = name

# %%
chart
# Out:
#                 ot    open    high     low   close        volume  \
# 0    1513123200000  272.00  330.00  260.00  290.01  9.565160e+03
# 1    1513209600000  290.01  302.72  252.00  272.40  9.631984e+03
# 2    1513296000000  272.40  314.21  239.99  294.00  1.657978e+04
# 3    1513382400000  294.00  305.00  285.00  293.97  9.102100e+03
# 4    1513468800000  293.01  328.80  290.00  311.40  1.468226e+04
# 5    1513555200000  311.23  360.96  277.00  352.00  1.721006e+04
# 6    1513641600000  352.00  366.96  303.01  338.48  2.319033e+04
# 7    1513728000000  336.05  357.00  260.00  302.70  3.158677e+04
# 8    1513814400000  303.80  325.16  267.01  302.00  2.621216e+04
# 9    1513900800000  303.00  315.00  177.58  250.99  8.123342e+04
# 10   1513987200000  250.99  301.52  214.91  253.44  3.870914e+04
# 11   1514073600000  253.44  277.00  220.03  262.90  3.343537e+04
# 12   1514160000000  262.90  277.50  251.40  261.20  2.441569e+04
# ...

# %%
plt.rcParams['figure.figsize'] = (20, 10)
plt.plot(chart['close'])
plt.show()
